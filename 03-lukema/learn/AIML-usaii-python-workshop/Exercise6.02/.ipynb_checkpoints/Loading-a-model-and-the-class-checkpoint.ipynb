# %%
##############################
# 1. libs
#

import pandas as pd
import os
import pickle
from sklearn.neural_network import MLPClassifier

# %%
##############################
# 2. load model
#

path = os.getcwd() + '/model_exercise.pkl'
with open(path, 'rb') as file:
    model = pickle.load(file)

# %%
##############################
# 3. predict
#

feature_header = ['age','workclass','education-num','marital-status','occupation','capital-gains','capital-loss','hours-per-week','native-country']

feature_data = [
    [-0.33, 0.67, 1, 1, 0, 0, 0.8, -1, 0.5]
]

data_frame = pd.DataFrame(feature_data, columns=feature_header)

pred = model.predict(data_frame)
print(pred)
