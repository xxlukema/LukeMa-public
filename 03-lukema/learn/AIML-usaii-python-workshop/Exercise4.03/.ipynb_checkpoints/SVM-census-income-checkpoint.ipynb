# %%
###############################
# 1. libs
#

import pandas as pd
from sklearn.svm import SVC

# %%
###############################
# 2. load data
#

# df = pd.read_csv('census_income_dataset_preprocessed.csv', header = None)
df = pd.read_csv('census_income_dataset_preprocessed.csv')

display(df.head(2))
# Out:
#    age  workclass  education-num  marital-status  occupation  capital-gains  \
# 0   39          6             13               4           0           2174
# 1   50          5             13               2           3              0
#
#    capital-loss  hours-per-week  native-country  target
# 0             0              40              38       0
# 1             0              13              38       0

# %%
###############################
# 3. split
#

X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

display(X.head(2))
display(Y.head(2))

display(X.shape, Y.shape)
# Out:
#    age  workclass  education-num  marital-status  occupation  capital-gains  \
# 0   39          6             13               4           0           2174
# 1   50          5             13               2           3              0
#
#    capital-loss  hours-per-week  native-country
# 0             0              40              38
# 1             0              13              38
# 0    0
# 1    0
# Name: target, dtype: int64
# (32561, 9)
# (32561,)

# %%
###############################
# 4. SVM model
#

model = SVC()
model.fit(X.values, Y.values)

# %%
###############################
# 5. predict
#

pred = model.predict([[39, 6, 13, 4, 0, 2174, 0, 40, 38]])
print(pred)
# Out:
# [0]
# C:\Users\lma\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
