# %%
##########################
# 1. libs
#

from bankMLPClass import BankMLP

# %%
##########################
# 2. params
#

# age, job, marital, education, default, balance, housing, loan, duration = 51, 10, 1, 3, 0, 825, 0, 0, 977
age, job, marital, education, default, balance, housing, loan, duration = 44, 10, 2, 2, 0, 29, 1, 0, 151

# %%
##########################
# 3. model
#

model = BankMLP()

# %%
##########################
# 4. call class
#

pred = model.predict(age, job, marital, education, default, balance, housing, loan, duration)
print(pred)
# Out:
# [0]
