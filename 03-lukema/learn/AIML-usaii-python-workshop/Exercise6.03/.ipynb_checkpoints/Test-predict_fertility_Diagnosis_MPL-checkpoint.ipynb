# %%
##########################
# 1. libs
#

import os
import pickle
from sklearn.neural_network import MLPClassifier

# %%
##########################
# 2. Load model
#

path = os.getcwd() + '/fertility_Diagnosis_MLP_model.pkl'
file = open(path, 'rb')

model = pickle.load(file)

# %%
##########################
# 3. predict
#

# 1,0.67,1,1,0,0,0.8,-1,0.25,N
# -0.33,0.5,1,1,0,-1,0.8,0,0.88,O  <============ wrong prediction for this instance
# -0.33,0.78,1,0,0,1,1,1,0.06,O

pred = model.predict([[1,0.67,1,1,0,0,0.8,-1,0.25], [-0.33,0.5,1,1,0,-1,0.8,0,0.88], [-0.33,0.78,1,0,0,1,1,1,0.06]])
print(pred)
# Out:
# ['N' 'N' 'O']
