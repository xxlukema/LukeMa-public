# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('circles.csv')
df.head(2)plt.scatter(data.iloc[:,0], data.iloc[:,1])
plt.show()
# Out:
#           0         1
# 0  0.393992 -0.416376
# 1  0.528243 -0.828242

# %%
plt.scatter(df.iloc[0:, 0], df.iloc[0:, 1])
plt.plot()
# Out:
# []
