# %%
# %pip install seaborn matplotlib scikit-learn

import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
actual = np.array(
  ['Dog','Dog','Dog','Not Dog','Dog','Not Dog','Dog','Dog','Not Dog','Not Dog']
)

predicted = np.array(
  ['Dog','Not Dog','Dog','Not Dog','Dog','Dog','Dog','Dog','Not Dog','Not Dog']
)

# %%
cm = confusion_matrix(actual, predicted, labels=['Dog', 'Not Dog'])
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[5 1]
#  [1 3]]

# %%
sns.heatmap(cm,
            annot=True, fmt='d', cmap='Blues',
            xticklabels=['Dog', 'Not Dog'],
            yticklabels=['Dog', 'Not Dog'])

plt.xlabel('Predicted', fontsize=13)
plt.ylabel('Actual', fontsize=13)
plt.title('Confusion Matrix')
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()

plt.gca().figure.subplots_adjust(left=0.2, right=0.8, top=0.8, bottom=0.2)
plt.show()

# %%
print(classification_report(actual, predicted, target_names=['Dog', 'Not Dog']))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.83      0.83      0.83         6
#      Not Dog       0.75      0.75      0.75         4
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10
