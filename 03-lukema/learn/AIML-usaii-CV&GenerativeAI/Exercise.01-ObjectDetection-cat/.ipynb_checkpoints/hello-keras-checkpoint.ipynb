# %%
##########################
# 0. pre-install
#

# !pip install keras_cv keras
# !pip install tensorflow
# Out:
# ...
#   Using cached keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached tensorflow_datasets-4.9.8-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached kagglehub-0.3.12-py3-none-any.whl.metadata (38 kB)
# ...
#   Using cached namex-0.0.9-py3-none-any.whl.metadata (322 bytes)
# ...
#   Using cached etils-1.12.2-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached simple_parsing-0.1.7-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached tensorflow_metadata-1.17.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached termcolor-3.0.1-py3-none-any.whl.metadata (6.1 kB)
# ...

# %%
##########################
# 1. lib
#

import json
import keras_cv
import numpy as np
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\keras_cv\src\version_check.py:18
#      17 try:
# ---> 18     import tensorflow as tf
#      19 except ModuleNotFoundError:
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 6
#       1 ##########################
#       2 # 1. lib
#       3 #
#       5 import json
# ----> 6 import keras_cv
#       7 import numpy as np
#       8 import keras
#
# File ~\anaconda3\Lib\site-packages\keras_cv\__init__.py:10
#       7 import os
#       9 # Import everything from /api/ into keras.
# ---> 10 from keras_cv.api import *  # noqa: F403
#      11 from keras_cv.api import __version__  # Import * ignores names start with "_".
# ...
